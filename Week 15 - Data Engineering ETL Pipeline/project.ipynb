# %% [markdown]
# ### Import Libraries

# %%
import pandas as pd 
import dotenv as lead_dotenv
import requests
import json 
import os

# %%
lead_dotenv()

API_key = os.getenv('Yt_API_Key')
if not API_key :
    print ('PAL')
